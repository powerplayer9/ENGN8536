# %% [markdown]
# # My first NN using Pytorch
# Python 3.6
#
# Pytorch 0.4.1
#
# CUDA 9.2

# %% [markdown]
# ### Loading all required Library functions

# %%
import torch
import torchvision
import matplotlib.pyplot as plt
import numpy as np
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim

import checkFile
import accuracyCheck
import LossCheck
import Train
import Net

# %% [markdown]
# ### Checking if device has a supported GPU

# %%
# # Check for CUDA
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
# # Assume that we are on a CUDA machine, then this should print a CUDA device:
print(device)
# Out:
# cuda:0

# %% [markdown]
# ### Setting Parameters

# %%
# Parameters
batch_size = 100
valid_size = 1000
Epoch = 20

# %% [markdown]
# ### Loading training, validation & test datasets

# %%
# Loading datasets & class labels
trainloader, validloader, testloader, classes = checkFile.initFiles(batch_size, valid_size)
# Out:
# Files already downloaded and verified
# TrainData Done
# Size Train Data: 50000
# TrainLoader Done
# Size Train: 490
# ValidLoader Done
# Size Train: 10
# Files already downloaded and verified
# TestSet Done
# Size Train: 10000
# TestLoader Done
# Size Train: 100

# %% [markdown]
# ## The CNN layers in order
#
# 5x5 Convolutional Layer with 32 filters, stride 1 and padding 2.
#
# ReLU Activation Layer
#
# Batch Normalization Layer
#
# 2x2 Max Pooling Layer with a stride of 2
#
# 3x3 Convolutional Layer with 64 filters, stride 1 and padding 1.
#
# ReLU Activation Layer
#
# Batch Normalization Layer
#
# 2x2 Max Pooling Layer with a stride of 2
#
# Fully-conneted layer with 1024 output units
#
# ReLU Activation Layer
#
# Fully-connected layer with 10 output units
#
# ### Defining the NN

# %%
net = Net.Net()
net.to(device)
# Out:
# Net(
#   (conv1): Conv2d(3, 32, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2))
#   (conv2): Conv2d(32, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (pool): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   (norm1): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (norm2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (fc1): Linear(in_features=4096, out_features=1024, bias=True)
#   (fc2): Linear(in_features=1024, out_features=10, bias=True)
# )

# %% [markdown]
# ### Initializing vectors to store Accuracy & Loss

# %%
# Initialize Accuracy List
trainAccuracy = np.zeros(1)
validAccuracy = np.zeros(1)

# Initialize Loss List
trainLoss = np.zeros(1)
validLoss = np.zeros(1)

# %% [markdown]
# ### Training the NN
# Using Adam Optimization parameters
#
# Learning Rate =  1e-3
#
# Betas         = (0.9, 0.999)

# %%
# Train your model
for epoch in range(Epoch):  # loop over the dataset multiple times

    trainLossTemp, net = Train.train(trainloader, net, 'Training', epoch)
    trainLoss = np.append(trainLoss, trainLossTemp)
    validLoss = np.append(validLoss, LossCheck.lossCheck(validloader, net, 'Validation', epoch))

    trainAccuracy = np.append(trainAccuracy, accuracyCheck.accuracyCheck(trainloader, net, 'Training'))
    validAccuracy = np.append(validAccuracy, accuracyCheck.accuracyCheck(validloader, net, 'Validation'))

print('Fin...')
# Out:
# [1,   490] Training loss: 1.070
# [1,    10] Validation loss: 1.114
# Accuracy of the network on the Training images: 59 %
# Accuracy of the network on the Validation images: 57 %
# [2,   490] Training loss: 0.858
# [2,    10] Validation loss: 0.944
# Accuracy of the network on the Training images: 67 %
# Accuracy of the network on the Validation images: 66 %
# [3,   490] Training loss: 0.851
# [3,    10] Validation loss: 1.042
# Accuracy of the network on the Training images: 70 %
# Accuracy of the network on the Validation images: 66 %
# [4,   490] Training loss: 0.786
# [4,    10] Validation loss: 0.793
# Accuracy of the network on the Training images: 73 %
# Accuracy of the network on the Validation images: 69 %
# [5,   490] Training loss: 0.732
# [5,    10] Validation loss: 0.736
# Accuracy of the network on the Training images: 74 %
# Accuracy of the network on the Validation images: 71 %
# [6,   490] Training loss: 0.601
# [6,    10] Validation loss: 0.838
# Accuracy of the network on the Training images: 76 %
# Accuracy of the network on the Validation images: 72 %
# [7,   490] Training loss: 0.795
# [7,    10] Validation loss: 0.725
# Accuracy of the network on the Training images: 76 %
# Accuracy of the network on the Validation images: 73 %
# [8,   490] Training loss: 0.734
# [8,    10] Validation loss: 0.784
# Accuracy of the network on the Training images: 78 %
# Accuracy of the network on the Validation images: 73 %
# [9,   490] Training loss: 0.699
# [9,    10] Validation loss: 0.820
# Accuracy of the network on the Training images: 79 %
# Accuracy of the network on the Validation images: 75 %
# [10,   490] Training loss: 0.849
# [10,    10] Validation loss: 0.671
# Accuracy of the network on the Training images: 80 %
# Accuracy of the network on the Validation images: 76 %
# [11,   490] Training loss: 0.603
# [11,    10] Validation loss: 0.557
# Accuracy of the network on the Training images: 81 %
# Accuracy of the network on the Validation images: 74 %
# [12,   490] Training loss: 0.730
# [12,    10] Validation loss: 0.652
# Accuracy of the network on the Training images: 80 %
# Accuracy of the network on the Validation images: 76 %
# [13,   490] Training loss: 0.467
# [13,    10] Validation loss: 0.622
# Accuracy of the network on the Training images: 82 %
# Accuracy of the network on the Validation images: 78 %
# [14,   490] Training loss: 0.407
# [14,    10] Validation loss: 0.685
# Accuracy of the network on the Training images: 82 %
# Accuracy of the network on the Validation images: 77 %
# [15,   490] Training loss: 0.531
# [15,    10] Validation loss: 0.785
# Accuracy of the network on the Training images: 83 %
# Accuracy of the network on the Validation images: 75 %
# [16,   490] Training loss: 0.689
# [16,    10] Validation loss: 0.541
# Accuracy of the network on the Training images: 83 %
# Accuracy of the network on the Validation images: 78 %
# [17,   490] Training loss: 0.473
# [17,    10] Validation loss: 0.538
# Accuracy of the network on the Training images: 83 %
# Accuracy of the network on the Validation images: 76 %
# [18,   490] Training loss: 0.367
# [18,    10] Validation loss: 0.707
# Accuracy of the network on the Training images: 85 %
# Accuracy of the network on the Validation images: 78 %
# [19,   490] Training loss: 0.349
# [19,    10] Validation loss: 0.650
# Accuracy of the network on the Training images: 85 %
# Accuracy of the network on the Validation images: 77 %
# [20,   490] Training loss: 0.346
# [20,    10] Validation loss: 0.629
# Accuracy of the network on the Training images: 86 %
# Accuracy of the network on the Validation images: 78 %
# Fin...

# %% [markdown]
# ### Deleting the 1st value of the accuracy & loss vectors
# Since the vector is initialized using zeros & rest are appended, we need to delete the 1st rogue variable.

# %%
# Deleting 1st index value
trainLoss = np.delete(trainLoss,0)
validLoss = np.delete(validLoss,0)
trainAccuracy = np.delete(trainAccuracy,0)
validAccuracy = np.delete(validAccuracy,0)

# Saving the network
#torch.save(net, './Save')

# %% [markdown]
# ### Plotting the Accuracy & Loss Vs Epoch

# %%
# Plots

# Making X axis
xAxis = np.arange(1, Epoch + 1 )


# Training loss vs. epochs
fig1 = plt.figure()
plt.plot(xAxis, trainLoss)
fig1.suptitle('Training Loss', fontsize=20)
plt.xlabel('Epochs', fontsize=18)
plt.ylabel('Loss', fontsize=16)

# Training accuracy vs. epochs
fig2 = plt.figure()
plt.plot(xAxis, trainAccuracy)
fig2.suptitle('Training Accuracy', fontsize=20)
plt.xlabel('Epochs', fontsize=18)
plt.ylabel('Accuracy', fontsize=16)

# Validation loss vs epochs
fig3 = plt.figure()
plt.plot(xAxis, validLoss)
fig3.suptitle('Validation Loss', fontsize=20)
plt.xlabel('Epochs', fontsize=18)
plt.ylabel('Loss', fontsize=16)

# Validation accuracy vs. epochs
fig4 = plt.figure()
plt.plot(xAxis, validAccuracy)
fig4.suptitle('Validation Accuracy', fontsize=20)
plt.xlabel('Epochs', fontsize=18)
plt.ylabel('Accuracy', fontsize=16)
# Out:
# Text(0,0.5,'Accuracy')
